# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_csv = pd.read_csv('/content/drive/My Drive/project tasks_data_mito.csv')

# %%
data_csv
# Out:
#               order_id  order_date     customer_name  ... discount    profit  year
# 0         AG-2011-2040  01-01-2011   Toby Braunhardt  ...      0.0  106.1400  2011
# 1        IN-2011-47883  01-01-2011       Joseph Holt  ...      0.1   36.0360  2011
# 2         HU-2011-1220  01-01-2011     Annie Thurman  ...      0.0   29.6400  2011
# 3      IT-2011-3647632  01-01-2011      Eugene Moren  ...      0.5  -26.0550  2011
# 4        IN-2011-47883  01-01-2011       Joseph Holt  ...      0.1   37.7700  2011
# ...                ...         ...               ...  ...      ...       ...   ...
# 51285   CA-2014-115427  12/31/2014        Erica Bern  ...      0.2    4.5188  2014
# 51286     MO-2014-2560  12/31/2014         Liz Preis  ...      0.0    0.4200  2014
# 51287   MX-2014-110527  12/31/2014  Charlotte Melton  ...      0.0   12.3600  2014
# 51288   MX-2014-114783  12/31/2014     Tamara Dahlen  ...      0.0    0.5600  2014
# ...

# %%
data_csv.shape
# Out:
# (51290, 14)

# %%
pip install mitoinstaller
# Out:
# ...
#   Created wheel for mitoinstaller: filename=mitoinstaller-0.0.41-cp37-none-any.whl size=8877 sha256=56e75ef0934609eaeee1344feefd0a043a38274931d6a5cf4fee5166d3856b93
#   Stored in directory: /root/.cache/pip/wheels/1d/8c/fd/869d749f59251d017308bb671941c023f70cbd00556e20feed
# Successfully built mitoinstaller
# ...

# %%
# Out:
#   File "<ipython-input-13-be1a71019424>", line 1
#     python -m mitoinstaller install
#                           ^
# SyntaxError: invalid syntax
