# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/DSLover Youtube/Udemy Courses.csv')

# %%
df
# Out:
#       course_id  ...              subject
# 0        288942  ...  Musical Instruments
# 1       1170074  ...  Musical Instruments
# 2       1193886  ...  Musical Instruments
# 3       1116700  ...  Musical Instruments
# 4       1120410  ...  Musical Instruments
# ...         ...  ...                  ...
# 3677     328960  ...      Web Development
# 3678     552700  ...  Musical Instruments
# 3679     631754  ...      Web Development
# 3680    1225194  ...     Business Finance
# 3681     964478  ...       Graphic Design
#
# [3682 rows x 11 columns]

# %% [markdown]
# **what are all differnt subject for which udemy is offering courses(all diffent value in a column)**

# %%
df.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# **Which subject has maximumn number of courses**

# %%
df.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %% [markdown]
# **show all courses having free of cost**

# %%
df[df.price == 'Free']
# Out:
#       course_id  ...              subject
# 41       286070  ...  Musical Instruments
# 49       696630  ...  Musical Instruments
# 57       955914  ...  Musical Instruments
# 67       270976  ...      Web Development
# 74      1214144  ...     Business Finance
# ...         ...  ...                  ...
# 3620     552598  ...      Web Development
# 3638    1068590  ...      Web Development
# 3652     752706  ...      Web Development
# 3674    1257976  ...  Musical Instruments
# 3680    1225194  ...     Business Finance
#
# [310 rows x 11 columns]

# %% [markdown]
# **Show all courses are paid**

# %%
df[df.is_paid == True]
# Out:
#       course_id  ...              subject
# 0        288942  ...  Musical Instruments
# 1       1170074  ...  Musical Instruments
# 2       1193886  ...  Musical Instruments
# 3       1116700  ...  Musical Instruments
# 4       1120410  ...  Musical Instruments
# ...         ...  ...                  ...
# 3676     498488  ...     Business Finance
# 3677     328960  ...      Web Development
# 3678     552700  ...  Musical Instruments
# 3679     631754  ...      Web Development
# 3681     964478  ...       Graphic Design
#
# [3372 rows x 11 columns]

# %% [markdown]
# **Number of top selling courses**

# %%
df.sort_values('num_subscribers', ascending= False)
# Out:
#       course_id  ...              subject
# 2230      41295  ...      Web Development
# 776       59014  ...      Web Development
# 3385     625204  ...      Web Development
# 640      173548  ...      Web Development
# 3316     764164  ...      Web Development
# ...         ...  ...                  ...
# 2290    1223240  ...  Musical Instruments
# 1267    1258666  ...     Business Finance
# 2070    1215926  ...     Business Finance
# 1931    1247992  ...     Business Finance
# 3165    1087466  ...     Business Finance
#
# [3682 rows x 11 columns]

# %% [markdown]
# **Number of least selling courses**

# %%
df.sort_values('num_subscribers', ascending= True)
# Out:
#       course_id  ...           subject
# 649     1233314  ...  Business Finance
# 3259    1232282  ...  Business Finance
# 3261    1275872  ...    Graphic Design
# 910      726314  ...    Graphic Design
# 3328     715476  ...  Business Finance
# ...         ...  ...               ...
# 3316     764164  ...   Web Development
# 640      173548  ...   Web Development
# 3385     625204  ...   Web Development
# 776       59014  ...   Web Development
# 2230      41295  ...   Web Development
#
# [3682 rows x 11 columns]

# %% [markdown]
# **Show all Grapich Design where price is below 100**

# %%
df[(df.subject == 'Graphic Design') & (df.price < '150')].sort_values('price')
# Out:
#       course_id  ...         subject
# 47      1269190  ...  Graphic Design
# 3479     575040  ...  Graphic Design
# 2713    1147664  ...  Graphic Design
# 2706    1243016  ...  Graphic Design
# 2704     950894  ...  Graphic Design
# 2576     482924  ...  Graphic Design
# 2491     771044  ...  Graphic Design
# 2481    1027080  ...  Graphic Design
# 2137     927186  ...  Graphic Design
# 1797    1266468  ...  Graphic Design
# 1786    1246168  ...  Graphic Design
# 1773    1012262  ...  Graphic Design
# 1697     654038  ...  Graphic Design
# 1616     996868  ...  Graphic Design
# 3594     908664  ...  Graphic Design
# 1444     490392  ...  Graphic Design
# 1071    1161864  ...  Graphic Design
# 1029    1160004  ...  Graphic Design
# 169      983444  ...  Graphic Design
# 184      638040  ...  Graphic Design
# 1568     727510  ...  Graphic Design
# 699      757900  ...  Graphic Design
# 520      978462  ...  Graphic Design
# 2748     269082  ...  Graphic Design
# ...

# %% [markdown]
# **List of courses are related with Python**

# %%
df[df.course_title.str.contains('Python')]
# Out:
#       course_id  ...           subject
# 216      599504  ...   Web Development
# 777       47963  ...   Web Development
# 814      631128  ...   Web Development
# 842      186096  ...   Web Development
# 1400     394832  ...   Web Development
# 1932    1038538  ...   Web Development
# 1969     902888  ...  Business Finance
# 2294     391546  ...   Web Development
# 2295    1063722  ...   Web Development
# 2341     546848  ...    Graphic Design
# 2906     368340  ...   Web Development
# 2908    1035940  ...   Web Development
# 2929     270808  ...   Web Development
# 2952    1170894  ...  Business Finance
# 2953    1070886  ...  Business Finance
# 2954    1196544  ...  Business Finance
# 2955     822444  ...   Web Development
# 2956     477702  ...   Web Development
# 2957    1035472  ...  Business Finance
# 2958     529828  ...  Business Finance
# 2959      70640  ...   Web Development
# 2960     523312  ...   Web Development
# 2962    1088656  ...  Business Finance
# ...

# %% [markdown]
# **what are courses published since 2015**

# %%
df.head()
# Out:
#    course_id  ...              subject
# 0     288942  ...  Musical Instruments
# 1    1170074  ...  Musical Instruments
# 2    1193886  ...  Musical Instruments
# 3    1116700  ...  Musical Instruments
# 4    1120410  ...  Musical Instruments
#
# [5 rows x 11 columns]

# %%
df.shape
# Out:
# (3682, 11)

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
df.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
df.published_timestamp = pd.to_datetime(df.published_timestamp)

# %%
df['Year'] = df.published_timestamp.dt.year

# %%
df.head(
    
)
# Out:
#    course_id  ...  Year
# 0     288942  ...  2014
# 1    1170074  ...  2017
# 2    1193886  ...  2017
# 3    1116700  ...  2017
# 4    1120410  ...  2017
#
# [5 rows x 12 columns]

# %%
df[df.Year == 2015]
# Out:
#       course_id  ...  Year
# 10       591880  ...  2015
# 16       302450  ...  2015
# 19       384928  ...  2015
# 23       550842  ...  2015
# 26       486240  ...  2015
# ...         ...  ...   ...
# 3675     551170  ...  2015
# 3676     498488  ...  2015
# 3677     328960  ...  2015
# 3678     552700  ...  2015
# 3679     631754  ...  2015
#
# [1014 rows x 12 columns]

# %% [markdown]
# **What are the max number of subcriber for each level of courses**

# %%
df.groupby('level').num_subscribers.max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64
