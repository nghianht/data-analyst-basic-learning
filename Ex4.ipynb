# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/covid_19_data.csv')

# %%
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
df.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# **1. Show the number of confirmed, dead an recovered cases in each Region**

# %%
df.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
df.groupby('Region')['Confirmed'].sum().sort_values(ascending = False)
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166543
# UK                        166441
#                           ...
# Sao Tome and Principe          8
# Papua New Guinea               8
# Bhutan                         7
# Western Sahara                 6
# Yemen                          6
# Name: Confirmed, Length: 187, dtype: int64

# %%
df.groupby("Region")['Confirmed','Recovered'].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# **2.Remove the column record where cofirmed is less than**

# %%
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
(df['Confirmed'] < 10).sum()
# Out:
# 17

# %%
df[df["Confirmed"] < 10]
# Out:
#           Date                             State  ... Deaths  Recovered
# 18   4/29/2020                               NaN  ...      0          5
# 98   4/29/2020                               NaN  ...      2          0
# 105  4/29/2020                               NaN  ...      1          6
# 126  4/29/2020                               NaN  ...      0          0
# 140  4/29/2020                               NaN  ...      0          4
# 177  4/29/2020                               NaN  ...      0          5
# 178  4/29/2020                               NaN  ...      0          1
# 184  4/29/2020                          Anguilla  ...      0          3
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba  ...      0          0
# 194  4/29/2020            British Virgin Islands  ...      1          3
# 203  4/29/2020      Diamond Princess cruise ship  ...      1          0
# 272  4/29/2020             Northwest Territories  ...      0          0
# ...

# %%
df = df[~(df["Confirmed"] < 10)]
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %% [markdown]
# **3) in which region, maximum cases are recorded**

# %%
df.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# Venezuela                 331      10        142
# Vietnam                   270       0        222
# West Bank and Gaza        344       2         71
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [180 rows x 3 columns]

# %%
df.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166536
# UK                 166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Name: Confirmed, dtype: int64

# %% [markdown]
# **4) in which region, minimum cases are recorded**

# %%
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
df.groupby('Region').Confirmed.sum().sort_values().head(10)
# Out:
# Region
# Suriname                            10
# Gambia                              10
# Holy See                            10
# Burundi                             11
# Seychelles                          11
# Nicaragua                           13
# Saint Kitts and Nevis               15
# Dominica                            16
# Namibia                             16
# Saint Vincent and the Grenadines    16
# Name: Confirmed, dtype: int64

# %% [markdown]
# **5. How many cases in India**

# %%
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
df.set_index('Region', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-2258691e854e> in <module>()
# ----> 1 df.set_index('Region', inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4553
#    4554         if missing:
# -> 4555             raise KeyError(f"None of {missing} are in the columns")
#    4556
#    4557         if inplace:
#
# KeyError: "None of ['Region'] are in the columns"

# %%
df.loc["India"]
# Out:
# Date         4/29/2020
# State              NaN
# Confirmed        33062
# Deaths            1079
# Recovered         8437
# Name: India, dtype: object

# %% [markdown]
# **Soluttion 2**

# %%
df[df.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# **6. Sort the entire data with Confirmed case in ascending other**

# %%
df.sort_values('Confirmed')
# Out:
#           Date                         State  ... Deaths  Recovered
# 285  4/29/2020                     Recovered  ...      0     120720
# 284  4/29/2020                     Recovered  ...      0      20327
# 203  4/29/2020  Diamond Princess cruise ship  ...      1          0
# 305  4/29/2020                         Tibet  ...      0          1
# 289  4/29/2020     Saint Pierre and Miquelon  ...      0          0
# ..         ...                           ...  ...    ...        ...
# 57   4/29/2020                           NaN  ...  24087      48228
# 168  4/29/2020                           NaN  ...  26097          0
# 80   4/29/2020                           NaN  ...  27682      71252
# 153  4/29/2020                           NaN  ...  24275     132929
# 265  4/29/2020                      New York  ...  23477          0
#
# [321 rows x 6 columns]

# %% [markdown]
# **7. Sort the entire data with Recover case in descending other**

# %%
df.sort_values(by =['Recovered'], ascending= False)
# Out:
#           Date           State   Region  Confirmed  Deaths  Recovered
# 153  4/29/2020             NaN    Spain     236899   24275     132929
# 285  4/29/2020       Recovered       US          0       0     120720
# 61   4/29/2020             NaN  Germany     161539    6467     120400
# 76   4/29/2020             NaN     Iran      93657    5957      73791
# 80   4/29/2020             NaN    Italy     203591   27682      71252
# ..         ...             ...      ...        ...     ...        ...
# 248  4/29/2020        Maryland       US      20849    1078          0
# 246  4/29/2020        Manitoba   Canada        275       6          0
# 243  4/29/2020       Louisiana       US      27660    1845          0
# 241  4/29/2020        Kentucky       US       4537     234          0
# 215  4/29/2020  Grand Princess   Canada         13       0          0
#
# [321 rows x 6 columns]

# %% [markdown]
# **DONEEEEEEEEEEEEEEEEEEEEEEEEEE**
